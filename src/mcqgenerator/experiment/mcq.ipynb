# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain.chat_models import ChatOpenAI

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
KEY=os.getenv("OPENAI_API_KEY")

# %%
print(KEY)
# Out:
# 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

# %%
llm=ChatOpenAI(openai_api_key=KEY,model_name="gpt-3.5-turbo",temperature=0.5)
